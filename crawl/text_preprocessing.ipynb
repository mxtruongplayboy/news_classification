# %%
import pandas as pd
import re
import py_vncorenlp

# %%
import pandas as pd
import os
import glob

# Đường dẫn tới thư mục chứa các file CSV
folder_path = r'E:\LEARN_5\XuLyNgonNguTuNhien\project\data_raw'

# Lấy danh sách tất cả các file CSV trong thư mục
csv_files = glob.glob(os.path.join(folder_path, '*.csv'))

# Đọc và gộp tất cả các file
df_list = [pd.read_csv(file) for file in csv_files]
merged_df = pd.concat(df_list, ignore_index=True)

# %%
merged_df.head()
# Out:
#                                                Title  \
# 0                5 công cụ AI hữu dụng ngoài ChatGPT
# 1  Figure AI - công ty robot hình người Mỹ bị ngh...
# 2  Camera giám sát - từ 'con mắt vô tri' thành tr...
# 3  CEO Microsoft: AI đảm nhiệm 30% việc viết mã l...
# 4     Robot pha đồ, bưng bê tại quán cà phê ở Hà Nội
#
#                                Date  \
# 0  Thứ hai, 5/5/2025, 05:00 (GMT+7)
# 1  Thứ sáu, 2/5/2025, 14:00 (GMT+7)
# 2  Thứ sáu, 2/5/2025, 07:00 (GMT+7)
# 3  Thứ sáu, 2/5/2025, 00:00 (GMT+7)
# 4  Thứ năm, 1/5/2025, 09:30 (GMT+7)
#
#                                          Description  \
# 0  Bên cạnh chatbot đình đám như ChatGPT, Gemini ...
# 1  Figure AI, công ty robot hình người tại Thung ...
# 2  Camera giám sát đang tiến hóa nhờ AI, giúp chú...
# 3  Microsoft cho biết AI đang đảm nhiệm khoảng 30...
# 4  Một cửa hàng ở Hà Nội sử dụng bốn robot thông ...
#
#                                              Content  \
# 0  Khi nhắc đến AI cho người dùng phổ thông, Chat...
# 1  Vào tháng 2, Figure AI bắt đầu đợt huy động vố...
# 2  "Trước đây, khi xảy ra mất trộm, nhiều người p...
# 3  "Có khoảng 20% hay 30% số code trong kho lưu t...
# 4  "Cửa hàng cà phê tương lai", nằm trên phố Vũ P...
#
#                                             Author Topic
# 0                       Huy Đức (theo Tom's Guide)    AI
# 1           Bảo Lâm (theo WSJ, Fortune, Mikekalil)    AI
# 2                                        Trọng Đạt    AI
# 3  Bảo Lâm - Huy Đức (theo Business Insider, CNBC)    AI
# 4                            Trọng Đạt - Lộc Chung    AI

# %%
# Thống kê các giá trị trùng nhau trong cột 'title'
duplicated_titles = merged_df['Title'].value_counts()
duplicated_titles = duplicated_titles[duplicated_titles > 1]

# Hiển thị kết quả
print("Các giá trị bị trùng trong cột 'title' và số lần xuất hiện:")
print(duplicated_titles)
# Out:
# Các giá trị bị trùng trong cột 'title' và số lần xuất hiện:
# Title
# Không tìm thấy tiêu đề                                              162
# Robot pha đồ, bưng bê tại quán cà phê ở Hà Nội                       16
# Thủ tướng phát động phong trào đổi mới sáng tạo và chuyển đổi số     15
# Robot dẫn đường bác sĩ sinh thiết ung thư                            15
# Thủ tướng kêu gọi người dân không ngừng đổi mới sáng tạo             15
#                                                                    ...
# Trợ lý AI Việt chiến thắng tại sự kiện công nghệ hàng đầu châu Á      2
# Cựu hacker Hiếu PC dùng AI nhận diện link lừa đảo                     2
# DeepSeek và xu hướng nhân tài AI rời Mỹ về quê nhà Trung Quốc         2
# Nữ kỹ sư Việt đầu tiên trở thành chuyên gia GDE của Google            2
# Hai lần tranh đấu vì con của mẹ đơn thân                              2
# Name: count, Length: 389, dtype: int64

# %%
# Xác định những giá trị 'title' bị trùng
duplicated_titles = merged_df['Title'].duplicated(keep=False)

# Loại bỏ toàn bộ các hàng có giá trị 'title' bị trùng
clean_df = merged_df[~duplicated_titles]

# %%
# Bước 1: Đọc dữ liệu từ file CSV
df = clean_df.copy()

# Bước 2: Giữ lại các cột cần thiết
df = df[['Title', 'Description', 'Content', 'Topic']]

# Bước 3: Loại bỏ giá trị thiếu
df = df.dropna(subset=['Title', 'Description', 'Content', 'Topic'])

df.head()
# Out:
#                                                Title  \
# 0                5 công cụ AI hữu dụng ngoài ChatGPT
# 1  Figure AI - công ty robot hình người Mỹ bị ngh...
# 3  CEO Microsoft: AI đảm nhiệm 30% việc viết mã l...
# 5  AI Grok của Musk sẽ trả lời bằng nguồn 'ngoài ...
# 6             OpenAI xác nhận ChatGPT quá 'nịnh hót'
#
#                                          Description  \
# 0  Bên cạnh chatbot đình đám như ChatGPT, Gemini ...
# 1  Figure AI, công ty robot hình người tại Thung ...
# 3  Microsoft cho biết AI đang đảm nhiệm khoảng 30...
# 5  Elon Musk cho biết mô hình Grok 3.5 của xAI sẽ...
# 6  OpenAI cho biết ChatGPT đưa ra những phản hồi ...
#
#                                              Content Topic
# 0  Khi nhắc đến AI cho người dùng phổ thông, Chat...    AI
# 1  Vào tháng 2, Figure AI bắt đầu đợt huy động vố...    AI
# 3  "Có khoảng 20% hay 30% số code trong kho lưu t...    AI
# 5  "Tuần tới, bản beta của Grok 3.5 dành cho ngườ...    AI
# 6  Tuần trước, OpenAI phát hành bản cập nhật mô h...    AI

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16003 entries, 0 to 17348
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        16003 non-null  object
#  1   Description  16003 non-null  object
#  2   Content      16003 non-null  object
#  3   Topic        16003 non-null  object
# dtypes: object(4)
# memory usage: 625.1+ KB

# %%
# Hàm đọc từ viết tắt từ file txt
def load_abbreviations(file_path):
    abbreviations = {}
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            # Loại bỏ khoảng trắng và chia theo dấu ":"
            parts = line.strip().split(":")
            if len(parts) == 2:
                # Lưu từ viết tắt và từ đầy đủ vào dictionary mà không thay đổi gì
                abbreviations[parts[0].strip()] = parts[1].strip()  # Giữ nguyên phần từ đầy đủ
    return abbreviations

abbreviations = load_abbreviations(r'E:\LEARN_5\XuLyNgonNguTuNhien\project\crawl\acronym.txt')

# %%
# Bước 4:  Hàm thay thế từ viết tắt trong văn bản
def replace_abbreviations_in_text(text):
    for abbr, full_text in abbreviations.items():
        text = re.sub(rf'\b{abbr}\b', full_text, text, flags=re.IGNORECASE)
    return text

df['Title'] = df['Title'].apply(replace_abbreviations_in_text)
df['Description'] = df['Description'].apply(replace_abbreviations_in_text)
df['Content'] = df['Content'].apply(replace_abbreviations_in_text)

# %%
# Bước 5: Loại bỏ dấu câu và ký tự đặc biệt
def clean_text(text):
    text = re.sub(r'[^\w\s]', '', text) 
    return text

df['Title'] = df['Title'].apply(clean_text)
df['Description'] = df['Description'].apply(clean_text)
df['Content'] = df['Content'].apply(clean_text)

# %%
# Bước 6: Tải mô hình VnCoreNLP và load nó
model = py_vncorenlp.VnCoreNLP(save_dir='E:/LEARN_5/XuLyNgonNguTuNhien/vncorenlp')

def tokenize_text(text):
    # Tokenize using VnCoreNLP
    return model.annotate_text(text)

# %%
# Bước 7: Tokenization (tách từ bằng py_vncorenlp)
df['Title_tokens'] = df['Title'].apply(tokenize_text)
df['Description_tokens'] = df['Description'].apply(tokenize_text)
df['Content_tokens'] = df['Content'].apply(tokenize_text)

df.head()
# Out:
#                                                Title  \
# 0  5 công cụ Trí tuệ nhân tạo hữu dụng ngoài ChatGPT
# 1  Figure Trí tuệ nhân tạo  công ty robot hình ng...
# 3  CEO Microsoft Trí tuệ nhân tạo đảm nhiệm 30 vi...
# 5  Trí tuệ nhân tạo Grok của Musk sẽ trả lời bằng...
# 6               OpenAI xác nhận ChatGPT quá nịnh hót
#
#                                          Description  \
# 0  Bên cạnh chatbot đình đám như ChatGPT Gemini h...
# 1  Figure Trí tuệ nhân tạo công ty robot hình ngư...
# 3  Microsoft cho biết Trí tuệ nhân tạo đang đảm n...
# 5  Elon Musk cho biết mô hình Grok 35 của xAI sẽ ...
# 6  OpenAI cho biết ChatGPT đưa ra những phản hồi ...
#
#                                              Content Topic  \
# 0  Khi nhắc đến Trí tuệ nhân tạo cho người dùng p...    AI
# 1  Vào tháng 2 Figure Trí tuệ nhân tạo bắt đầu đợ...    AI
# 3  Có khoảng 20 hay 30 số code trong kho lưu trữ ...    AI
# 5  Tuần tới bản beta của Grok 35 dành cho người đ...    AI
# 6  Tuần trước OpenAI phát hành bản cập nhật mô hì...    AI
#
#                                         Title_tokens  \
# 0  {0: [{'index': 1, 'wordForm': '5', 'posTag': '...
# 1  {0: [{'index': 1, 'wordForm': 'Figure_Trí', 'p...
# 3  {0: [{'index': 1, 'wordForm': 'CEO', 'posTag':...
# 5  {0: [{'index': 1, 'wordForm': 'Trí_tuệ_nhân_tạ...
# 6  {0: [{'index': 1, 'wordForm': 'OpenAI', 'posTa...
#
#                                   Description_tokens  \
# 0  {0: [{'index': 1, 'wordForm': 'Bên', 'posTag':...
# 1  {0: [{'index': 1, 'wordForm': 'Figure_Trí', 'p...
# 3  {0: [{'index': 1, 'wordForm': 'Microsoft', 'po...
# 5  {0: [{'index': 1, 'wordForm': 'Elon_Musk', 'po...
# 6  {0: [{'index': 1, 'wordForm': 'OpenAI', 'posTa...
#
#                                       Content_tokens
# 0  {0: [{'index': 1, 'wordForm': 'Khi', 'posTag':...
# 1  {0: [{'index': 1, 'wordForm': 'Vào', 'posTag':...
# 3  {0: [{'index': 1, 'wordForm': 'Có', 'posTag': ...
# 5  {0: [{'index': 1, 'wordForm': 'Tuần', 'posTag'...
# 6  {0: [{'index': 1, 'wordForm': 'Tuần', 'posTag'...

# %%
# Đọc stopwords từ file
def load_stopwords(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        stopwords = f.read().splitlines()
    return stopwords

stopwords = load_stopwords('E:\\LEARN_5\\XuLyNgonNguTuNhien\\project\\crawl\\stopwords.txt')

# %%
# copy bản sao df
df_copy = df.copy()
# Bước 8: Loại bỏ từ dừng (stopwords) sau khi tokenize và lấy wordForm
# Hàm lấy wordForm và chuyển thành chữ thường
import re

# Hàm lấy wordForm và chuyển thành chữ thường
def extract_wordforms(tokens_dict):
    # Lấy danh sách các token từ phần tử có key 0
    tokens = tokens_dict.get(0, [])
    # Lấy wordForm và chuyển thành chữ thường
    return [token['wordForm'].lower() for token in tokens if isinstance(token, dict) and token.get('wordForm')]

# Hàm loại bỏ stopwords
def remove_stopwords(wordforms, stopwords):
    # Loại bỏ các wordForm có trong stopwords
    return [word for word in wordforms if word not in stopwords]

# Hàm loại bỏ số
def remove_numbers(wordforms):
    # Loại bỏ các từ chứa số
    return [word for word in wordforms if not re.search(r'\d', word)]

# Hàm ghép lại thành câu
def join_to_sentence(wordforms):
    return ' '.join(wordforms)

# Áp dụng cho các cột trong DataFrame
df['Title_cleaned'] = df['Title_tokens'].apply(lambda x: join_to_sentence(remove_numbers(remove_stopwords(extract_wordforms(x), stopwords))))
df['Description_cleaned'] = df['Description_tokens'].apply(lambda x: join_to_sentence(remove_numbers(remove_stopwords(extract_wordforms(x), stopwords))))
df['Content_cleaned'] = df['Content_tokens'].apply(lambda x: join_to_sentence(remove_numbers(remove_stopwords(extract_wordforms(x), stopwords))))

# Kiểm tra kết quả
df.head()
# Out:
#                                                Title  \
# 0  5 công cụ Trí tuệ nhân tạo hữu dụng ngoài ChatGPT
# 1  Figure Trí tuệ nhân tạo  công ty robot hình ng...
# 3  CEO Microsoft Trí tuệ nhân tạo đảm nhiệm 30 vi...
# 5  Trí tuệ nhân tạo Grok của Musk sẽ trả lời bằng...
# 6               OpenAI xác nhận ChatGPT quá nịnh hót
#
#                                          Description  \
# 0  Bên cạnh chatbot đình đám như ChatGPT Gemini h...
# 1  Figure Trí tuệ nhân tạo công ty robot hình ngư...
# 3  Microsoft cho biết Trí tuệ nhân tạo đang đảm n...
# 5  Elon Musk cho biết mô hình Grok 35 của xAI sẽ ...
# 6  OpenAI cho biết ChatGPT đưa ra những phản hồi ...
#
#                                              Content Topic  \
# 0  Khi nhắc đến Trí tuệ nhân tạo cho người dùng p...    AI
# 1  Vào tháng 2 Figure Trí tuệ nhân tạo bắt đầu đợ...    AI
# 3  Có khoảng 20 hay 30 số code trong kho lưu trữ ...    AI
# 5  Tuần tới bản beta của Grok 35 dành cho người đ...    AI
# 6  Tuần trước OpenAI phát hành bản cập nhật mô hì...    AI
#
#                                         Title_tokens  \
# 0  {0: [{'index': 1, 'wordForm': '5', 'posTag': '...
# 1  {0: [{'index': 1, 'wordForm': 'Figure_Trí', 'p...
# 3  {0: [{'index': 1, 'wordForm': 'CEO', 'posTag':...
# 5  {0: [{'index': 1, 'wordForm': 'Trí_tuệ_nhân_tạ...
# 6  {0: [{'index': 1, 'wordForm': 'OpenAI', 'posTa...
#
#                                   Description_tokens  \
# 0  {0: [{'index': 1, 'wordForm': 'Bên', 'posTag':...
# 1  {0: [{'index': 1, 'wordForm': 'Figure_Trí', 'p...
# 3  {0: [{'index': 1, 'wordForm': 'Microsoft', 'po...
# 5  {0: [{'index': 1, 'wordForm': 'Elon_Musk', 'po...
# 6  {0: [{'index': 1, 'wordForm': 'OpenAI', 'posTa...
#
#                                       Content_tokens  \
# 0  {0: [{'index': 1, 'wordForm': 'Khi', 'posTag':...
# 1  {0: [{'index': 1, 'wordForm': 'Vào', 'posTag':...
# 3  {0: [{'index': 1, 'wordForm': 'Có', 'posTag': ...
# 5  {0: [{'index': 1, 'wordForm': 'Tuần', 'posTag'...
# 6  {0: [{'index': 1, 'wordForm': 'Tuần', 'posTag'...
#
#                                        Title_cleaned  \
# 0          công_cụ trí_tuệ_nhân_tạo hữu_dụng chatgpt
# 1  figure_trí tuệ nhân_tạo công_ty robot hình mỹ ...
# 3  ceo microsoft trí_tuệ_nhân_tạo đảm_nhiệm viết ...
# 5        trí_tuệ_nhân_tạo grok musk trả_lời internet
# 6                   openai xác_nhận chatgpt nịnh_hót
#
#                                  Description_cleaned  \
# 0  cạnh chatbot đình_đám chatgpt_gemini copilot c...
# 1  figure_trí tuệ nhân_tạo công_ty robot hình thu...
# 3  microsoft trí_tuệ_nhân_tạo đảm_nhiệm viết code...
# 5  elon_musk mô_hình grok xai cung_cấp câu trả_lờ...
# 6  openai chatgpt phản_hồi nịnh_hót cập_nhật công...
#
#                                      Content_cleaned
# 0  nhắc trí_tuệ_nhân_tạo phổ_thông chatgpt quen_t...
# 1  figure_trí tuệ nhân_tạo đợt huy_động vốn giới_...
# 3  code kho lưu_trữ dự_án viết trí_tuệ_nhân_tạo c...
# 5  tuần beta grok đăng_ký supergrok giới_thiệu tr...
# 6  tuần openai phát_hành cập_nhật mô_hình chatgpt...

# %%
# Bước 9: Kết hợp các cột văn bản thành một cột duy nhất
df['text'] = df['Title_cleaned'] + " " + df['Description_cleaned'] + " " + df['Content_cleaned']

df.head()

# Bước 10: Lưu lại dữ liệu đã xử lý vào file CSV
df.to_csv(r'E:\LEARN_5\XuLyNgonNguTuNhien\project\data\cleaned_news_data.csv', index=False)

# %%
import pandas as pd

# Đọc file CSV
df = pd.read_csv(r'E:\LEARN_5\XuLyNgonNguTuNhien\project\data\cleaned_data.csv')  # thay đường dẫn phù hợp
df.head()
# # Lấy 2 cột 'text' và 'Topic'
# selected_df = df[['text', 'Topic']]

# # Hiển thị 5 dòng đầu tiên để kiểm tra
# print(selected_df.head())
# Out:
#                                                 text Topic
# 0  công_cụ trí_tuệ_nhân_tạo hữu_dụng chatgpt cạnh...    AI
# 1  figure_trí tuệ nhân_tạo công_ty robot hình mỹ ...    AI
# 2  ceo microsoft trí_tuệ_nhân_tạo đảm_nhiệm viết ...    AI
# 3  trí_tuệ_nhân_tạo grok musk trả_lời internet el...    AI
# 4  openai xác_nhận chatgpt nịnh_hót openai chatgp...    AI

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16003 entries, 0 to 16002
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                16003 non-null  object
#  1   Description          16003 non-null  object
#  2   Content              16003 non-null  object
#  3   Topic                16003 non-null  object
#  4   Title_tokens         16003 non-null  object
#  5   Description_tokens   16003 non-null  object
#  6   Content_tokens       16003 non-null  object
#  7   Title_cleaned        16002 non-null  object
#  8   Description_cleaned  16003 non-null  object
#  9   Content_cleaned      16003 non-null  object
#  10  text                 16003 non-null  object
# dtypes: object(11)
# memory usage: 1.3+ MB

# %%
selected_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16003 entries, 0 to 16002
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    16003 non-null  object
#  1   Topic   16003 non-null  object
# dtypes: object(2)
# memory usage: 250.2+ KB

# %%
selected_df.to_csv(r'E:\LEARN_5\XuLyNgonNguTuNhien\project\data\cleaned_data.csv', index=False)
